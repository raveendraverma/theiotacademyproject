# %% [markdown]
# # RAHUL DHIMAN

# %%
pip install notebook pandas numpy matplotlib seaborn openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#LOADING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset
marks_df = pd.read_excel('"Assignment.xlsx"', sheet_name='Marks')
attendance_df = pd.read_excel('"Assignment.xlsx"', sheet_name='Attendance')

print("Marks Data Sample:", marks_df.head())
print("Attendance Data Sample:\n", attendance_df.head())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[24], line 2
#       1 # file path
# ----> 2 marks_df = pd.read_excel('"Assignment.xlsx"', sheet_name='Marks')
#       3 attendance_df = pd.read_excel('"Assignment.xlsx"', sheet_name='Attendance')
#       5 print("Marks Data Sample:", marks_df.head())
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
# ...
